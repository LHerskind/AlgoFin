# %%
import fix_yahoo_finance as yf
import datetime
import matplotlib.pyplot as plt
import numpy as np

# %%
stocks = ["PNDORA.CO"]
start = datetime.datetime(2012,5,31)
end = datetime.datetime(2019,1,14)
df = yf.download(stocks, start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-05-31   60.900002   61.000000   59.900002   61.000000   54.156296
# 2012-06-01   61.299999   61.299999   56.500000   58.500000   51.936775
# 2012-06-04   57.750000   59.500000   56.250000   59.450001   52.780193
# 2012-06-06   60.000000   61.900002   58.000000   61.450001   54.555805
# 2012-06-07   62.049999   62.799999   59.650002   61.400002   54.511421
# 2012-06-08   60.500000   62.200001   59.349998   62.200001   55.221672
# 2012-06-11   63.200001   63.349998   60.500000   61.700001   54.777763
# 2012-06-12   60.849998   63.000000   60.500000   63.000000   55.931911
# 2012-06-13   62.400002   62.700001   60.299999   60.900002   54.067516
# 2012-06-14   60.900002   61.000000   59.099998   60.000000   53.268490
# 2012-06-15   60.099998   63.000000   60.099998   62.200001   55.221672
# 2012-06-18   62.750000   63.500000   60.250000   60.299999   53.534828
# ...

# %%
data = df["Open"]
plt.plot(data)
plt.show()

# %%
def predict_next(prev, percent):
    mean = np.mean(prev)
    if prev[-1] / mean > 1 + percent:
        return 1
    if prev[-1] / mean < 1 - percent:
        return -1
    else:
        return 0

# %%
money = 1000
owns = 0
for i in range(len(actions)):
    if actions[i] == 1 and money > data[i]:
        owns = owns + 1
        money = money - data[i]
        #print("Buying at ", data[i])
    if actions[i] == -1 and owns > 0:
        money = money + data[i]*owns
        #print("Selling ", owns, " at ", data[i])
        owns = 0
print(money, owns)
print("Totalmoney: ", money + owns*data[-1])

# %%
# Out:
# 4.538587601360013

# %%
def test_stock(days_to_check, company, percent):
    #stocks = [company]
    #start = datetime.datetime(2018,1,1)
    #end = datetime.datetime(2019,1,1)
    #df = yf.download(stocks, start=start, end=end)
    
    #data = df["Open"]
    
    actions = []
    for i in range(days_to_check, days_to_check+len(data)):
        actions.append(predict_next(data[(i-days_to_check):i], percent))

    plt.figure(figsize=(20,5))
    plt.plot(data)
    plt.show()
        
    trades = 0
    
    start_money = 100000
    money = start_money
    owns = 0
    
    balances = [money]
    amounts = [owns]

    for i in range(len(actions)):
        if actions[i] == 1 and money > data[i]:
            owns = owns + 1
            money = money - data[i]
            trades = trades + 1
            balances.append(money)
            amounts.append(owns)
            #print("Buying at ", data[i])
        elif actions[i] == -1 and owns > 0:
            money = money + data[i]*owns
            #print("Selling ", owns, " at ", data[i])
            trades = trades + 1
            owns = 0
            amounts.append(owns)
            balances.append(money)
        else:
            balances.append(money)
            amounts.append(owns)

    plt.figure(figsize=(20,5))        
    plt.plot(balances)
    plt.show()

    plt.figure(figsize=(20,5))        
    plt.plot(amounts)
    plt.show()
    
    print(money, owns, trades)
    print("Totalmoney: ", (money + owns*data[-1])/start_money)
    print("Holder: ", data[-1]/data[0])

# %%
test_stock(10, "^GSPC", 0.005)
# Out:
# [*********************100%***********************]  1 of 1 downloaded
# 83422.74586399997 8 116
# Totalmoney:  1.0341426539199998
# Holder:  0.9311443251082957
